# %% [markdown]
# I just feel like a Jupyter Notebook should exist

# %%
import pandas as pd
import numpy as np
import requests
import time
import json
from datetime import datetime

# %%
url1 = 'https://guide.michelin.com/us/en/public-rest/references.json'

# %%
reference = requests.get(url1)
reference
# Out:
# <Response [403]>

# %%
referenceData = reference.json()
referenceData
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~/anaconda3/lib/python3.11/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File ~/anaconda3/lib/python3.11/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File ~/anaconda3/lib/python3.11/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 referenceData = reference.json()
#       2 referenceData
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
biggestLink = 'https://8nvhrd7onv-dsn.algolia.net/1/indexes/*/queries?x-algolia-agent=Algolia%20for%20JavaScript%20(5.47.0)%3B%20Lite%20(5.47.0)%3B%20Browser&x-algolia-api-key=3222e669cf890dc73fa5f38241117ba5&x-algolia-application-id=8NVHRD7ONV'

# %%
agoliaPW = {"x-agolia-api-key":"3222e669cf890dc73fa5f38241117ba5",
           "x-agolia-application-id":"8NVHRD7ONV"}

# %%
michelinIndex = '{"requests":[{"indexName":"prod-restaurants-en","aroundLatLngViaIP":true,"aroundRadius":"all","attributesToHighlight":[],"attributesToRetrieve":["_geoloc","region","area_name","chef","city","country","cuisines","currency","good_menu","identifier","image","images","main_image","michelin_award","name","slug","new_table","offers","offers_size","online_booking","other_urls","region_code","site_slug","site_name","take_away","delivery","price_category","currency_symbol","url","green_star","hotel_selection","objectType"],"facets":["area_slug","booking_provider","categories.lvl0","city.slug","country.cname","country.slug","cuisines.slug","days_open","delivery","delivery_provider","distinction.slug","facilities.slug","good_menu","green_star.slug","meal_times","new_table","offers","online_booking","price_category.slug","region.slug","special_diets.slug","tag_thematic.slug","take_away","with_michelin_guide_hotels"],"filters":"status:Published","hitsPerPage":48,"maxValuesPerFacet":200,"optionalFilters":["sites:us"],"page":0,"query":""}]}'

# %%
bigJson = bigData.json()
bigJson
# Out:
# {'message': 'indexName is not valid', 'status': 400}

# %%
with open("pageOne.json", "r") as f:
    rawJSON = json.load(f)

# %%
handCrushed = json.loads(rawJSON)

# %%
results = handCrushed.get("results")
hits = results[0]

# %%
hits.keys()
hitSquared = hits["hits"]

# %%
#When doing the Steely Dan thing I seem to have solely zoomed in on the first restaurant on the list. 
steelyDan = hitSquared[0]
manOfSteel = hitSquared[1]
steelyDan.keys()
#Got some valuable info though
# Out:
# dict_keys(['_geoloc', 'area_name', 'image', 'images', 'chef', 'city', 'country', 'currency', 'currency_symbol', 'good_menu', 'green_star', 'identifier', 'main_image', 'michelin_award', 'name', 'new_table', 'offers', 'offers_size', 'online_booking', 'price_category', 'region', 'region_code', 'site_name', 'site_slug', 'slug', 'take_away', 'delivery', 'hotel_selection', 'cuisines', 'url', 'other_urls', 'objectType', 'objectID', '_snippetResult'])

# %%
len(hitSquared)
# Out:
# 48

# %%
#Using this, I can make the for loop to parse out every single restaurant in that little JSON file, though I fear it may not be the only one.
hitSquared[0]['_snippetResult']
# Out:
# {'main_desc': {'value': "La'\xa0Shukran feels like a discovery, as you'll need",
#   'matchLevel': 'none'}}

# %%
all_rows = []
#I do not need all of this data, I just pulled it cause I thought I would but nah.
for restaurant in hitSquared:
    geo_loc = restaurant["_geoloc"]
    for coord in geo_loc:
        lat = geo_loc['lat']
        long = geo_loc.get('lng')
    area_name = restaurant["area_name"]
    image_link = restaurant['image']
    image_copyright = restaurant['images']
    for photo in image_copyright:
        for unneeded in photo:
            copyright = photo.get('copyright')
            photo_id = photo.get('identifier')
            photo_order = photo.get('order')
            photo_topic = photo.get('topic')
            photo_link = photo.get('url')
    chef = restaurant["chef"]
    city = restaurant["city"]
    for town in city:
        cityName = city.get("name")
        citySlug = city.get('slug')
        cityExonym = city.get('exonyms')
    country = restaurant["country"]
    for cont in country:
        countryName = country.get("name")
        countrySlug = country.get('slug')
        countryExonym = country.get('exonyms')
        countryCode = country.get('code')
        countryCName = country.get('cname')
    currency = restaurant["currency"]
    moneySign = restaurant["currency_symbol"]
    good_menu = restaurant["good_menu"]
    green_star = restaurant["green_star"]
    restaurantID = restaurant["identifier"]
    mainImage = restaurant["main_image"]
    for credit in mainImage:
        crit = mainImage.get('copyright')
        crid = mainImage.get('identifier')
        croder = mainImage.get('order')
        cropic = mainImage.get('topic')
        crurl = mainImage.get('url')
        crourse = mainImage.get('source')
    award = restaurant["michelin_award"]
    name = restaurant["name"]
    newTable = restaurant["new_table"]
    offers = restaurant["offers"]
    offerSize = restaurant["offers_size"]
    online_booking = restaurant["online_booking"]
    pricing = restaurant["price_category"]
    for price in pricing:
        price_code = pricing.get('code')
        price_desc = pricing.get('label')
        price_category = pricing.get("slug")
    region = restaurant["region"]
    for regin in region:
        rName = region.get('name')
        rSlug = region.get('slug')
        rExo = region.get('exonyms')
    region_code = restaurant["region_code"]
    siteName = restaurant["site_name"]
    siteSlug = restaurant["site_slug"]
    restaurantSlug = restaurant["slug"]
    takeaway = restaurant["take_away"]
    delivery = restaurant["delivery"]
    hotel_selection = restaurant["hotel_selection"]
    #for hotel in hotel_selection:
    #    hotelName = hotel_selection.get("name")
    #    distinction = hotel_selection.get("distinction_score")
    #    feebackMeter = hotel_selection.get("feedback_meter_score")
    #    style = hotel_selection.get("criteria_style")
    cuisines = restaurant["cuisines"]
    if len(cuisines) > 1:
        cuisineLabel = cuisines[0]['label']
        cuisineLabel2 = cuisines[1]['label']
    else:
        cuisineLabel = cuisines[0]['label']
        cuisineLabel2 = "NA"
    #for form in cuisines:
    #    cuisineCode = form.get('code')
    #    cuisineLabel = form.get("label")
    #    cuisineSlug = form.get('slug')
    #restaurantURL = restaurant["url"]
    altURL = restaurant["other_urls"]
    for why in altURL:
        otherURL = why
    isRestaurant = restaurant["objectType"]
    resID = restaurant["objectID"]
        
    all_rows.append({
        "Name": name,
        "Award": award,
        "Food Style 1": cuisineLabel,
        "Food Style 2": cuisineLabel2,
        "Pricing": price_category,
        "Online Booking?": online_booking,
        "Take Away?": takeaway,
        "Delivery?": delivery,
        "Chef": chef,
        "City": cityName,
        "Area": area_name,
        "Country": countryName,
        "Currency": currency,
        "Good Menu?": good_menu,
        "Green Star?": green_star
        #"Hotel Name": hotelName,
        #"Distinction Score": distinction,
        #"Feedback": feedbackMeter,
        #"Hotel Style": style,
    })

# %%
cuisines[0]['label']
# Out:
# 'Chinese'

# %%
michelinDataframe = pd.DataFrame(all_rows)
michelinDataframe
# Out:
#                            Name         Award    Food Style 1  \
# 0                    La'Shukran      selected  Middle Eastern
# 1                    Café Riggs      selected    Contemporary
# 2                        Xiquet      ONE_STAR         Spanish
# 3                 Rooster & Owl      ONE_STAR    Contemporary
# 4              Family Ethiopian      selected       Ethiopian
# 5                      Masseria      ONE_STAR         Italian
# 6                           Ris      selected        American
# 7                     Thip Khao      selected             Lao
# 8              Toki Underground  BIB_GOURMAND        Japanese
# 9                          Ellē  BIB_GOURMAND    Contemporary
# 10             Blue Duck Tavern      selected        American
# 11                     The Saga      selected         Spanish
# 12                 Menya Hosaki  BIB_GOURMAND        Japanese
# 13                      Del Mar      selected         Spanish
# 14                        Dōgon      selected         African
# 15                    Annabelle      selected    Contemporary
# 16                    Chaplin's      selected           Asian
# 17                   Dauphine's  BIB_GOURMAND          Creole
# 18                        Royal      selected  Latin American
# 19            Taqueria Habanero  BIB_GOURMAND         Mexican
# 20              Queen’s English  BIB_GOURMAND         Chinese
# 21                        Kappo      selected        Japanese
# 22  Beloved BBQ at Love, Makoto      selected        Japanese
# 23      Omakase at Barracks Row      ONE_STAR        Japanese
# 24                         Jônt     TWO_STARS    Contemporary
# 25                   The Dabney      ONE_STAR        American
# 26                       Elmina      selected         African
# 27                    Karravaan      selected           Asian
# 28                         Daru  BIB_GOURMAND          Indian
# 29         El Secreto de Rosita      selected        Peruvian
# 30               Reveler's Hour      selected    Contemporary
# 31                  Moon Rabbit      selected      Vietnamese
# 32            Hank’s Oyster Bar      selected         Seafood
# 33                    La Tejana  BIB_GOURMAND         Mexican
# 34                        Shōtō      selected        Japanese
# 35                       Rasika      selected          Indian
# 36                       Lutèce      selected    Contemporary
# 37        Elcielo Washington DC      ONE_STAR       Colombian
# 38                   Astoria DC  BIB_GOURMAND           Asian
# 39                  San Lorenzo      selected         Italian
# 40              Ottoman Taverna      selected         Turkish
# 41       minibar by José Andrés     TWO_STARS    Contemporary
# 42                      Elfegne      selected       Ethiopian
# 43                       Maydān      selected  Middle Eastern
# 44        Karizma Modern Indian  BIB_GOURMAND          Indian
# 45                      Maketto  BIB_GOURMAND           Asian
# 46                       Yellow  BIB_GOURMAND  Middle Eastern
# 47                  Chang Chang      selected         Chinese
#
#              Food Style 2     Pricing  Online Booking?  Take Away?  Delivery?  \
# 0                      NA     premium                0           0          0
# 1                  French     premium                1           0          0
# 2                      NA      luxury                1           0          0
# 3                  Fusion     premium                1           0          0
# 4        Regional Cuisine   mid-range                0           0          0
# 5        Regional Cuisine      luxury                1           0          0
# 6                      NA   mid-range                1           0          0
# 7                      NA   mid-range                1           0          0
# 8                   Ramen  affordable                1           0          0
# 9                  Bakery   mid-range                1           0          0
# 10  American Contemporary      luxury                0           0          0
# 11                     NA      luxury                1           0          0
# 12                  Ramen   mid-range                0           0          0
# 13                 Basque      luxury                0           0          0
# 14              Caribbean      luxury                0           0          0
# 15               American     premium                1           0          0
# 16                  Ramen   mid-range                1           0          0
# 17               Creative   mid-range                1           0          0
# 18                     NA   mid-range                1           0          0
# 19                     NA   mid-range                0           0          0
# 20           Contemporary   mid-range                1           0          0
# 21                     NA      luxury                1           0          0
# 22             Steakhouse     premium                1           0          0
# 23                  Sushi      luxury                0           0          0
# 24                     NA      luxury                1           0          0
# 25           Contemporary      luxury                1           0          0
# 26           Contemporary      luxury                1           0          0
# 27                     NA     premium                0           0          0
# 28       Regional Cuisine   mid-range                1           0          0
# 29         Latin American     premium                1           0          0
# 30                Italian     premium                1           0          0
# 31                     NA     premium                1           0          0
# 32    Oyster Specialities   mid-range                1           0          0
# 33                     NA  affordable                0           0          0
# 34                     NA     premium                1           0          0
# 35                     NA     premium                1           0          0
# 36               American   mid-range                1           0          0
# 37           Contemporary      luxury                1           0          0
# 38                Sichuan   mid-range                0           0          0
# 39                     NA     premium                1           0          0
# 40                     NA   mid-range                1           0          0
# 41                     NA      luxury                1           0          0
# 42       Regional Cuisine   mid-range                0           0          0
# 43                 Grills     premium                1           0          0
# 44           Contemporary   mid-range                1           0          0
# 45                     NA   mid-range                1           0          0
# 46                     NA   mid-range                0           0          0
# 47                  Asian     premium                1           0          0
#
#     Chef        City           Area Country Currency  Good Menu? Green Star?
# 0   None  Washington           None     USA      USD           0        None
# 1   None  Washington  Washington DC     USA      USD           0        None
# 2   None  Washington  Washington DC     USA      USD           0        None
# 3   None  Washington  Washington DC     USA      USD           0        None
# 4   None  Washington  Washington DC     USA      USD           0        None
# 5   None  Washington  Washington DC     USA      USD           0        None
# 6   None  Washington  Washington DC     USA      USD           0        None
# 7   None  Washington  Washington DC     USA      USD           0        None
# 8   None  Washington  Washington DC     USA      USD           0        None
# 9   None  Washington  Washington DC     USA      USD           0        None
# 10  None  Washington  Washington DC     USA      USD           0        None
# 11  None  Washington           None     USA      USD           0        None
# 12  None  Washington  Washington DC     USA      USD           0        None
# 13  None  Washington  Washington DC     USA      USD           0        None
# 14  None  Washington  Washington DC     USA      USD           0        None
# 15  None  Washington  Washington DC     USA      USD           0        None
# 16  None  Washington  Washington DC     USA      USD           0        None
# 17  None  Washington  Washington DC     USA      USD           0        None
# 18  None  Washington  Washington DC     USA      USD           0        None
# 19  None  Washington  Washington DC     USA      USD           0        None
# 20  None  Washington  Washington DC     USA      USD           0        None
# 21  None  Washington  Washington DC     USA      USD           0        None
# 22  None  Washington  Washington DC     USA      USD           0        None
# 23  None  Washington  Washington DC     USA      USD           0        None
# 24  None  Washington  Washington DC     USA      USD           0        None
# 25  None  Washington  Washington DC     USA      USD           0        None
# 26  None  Washington           None     USA      USD           0        None
# 27  None  Washington           None     USA      USD           0        None
# 28  None  Washington  Washington DC     USA      USD           0        None
# 29  None  Washington  Washington DC     USA      USD           0        None
# 30  None  Washington  Washington DC     USA      USD           0        None
# 31  None  Washington  Washington DC     USA      USD           0        None
# 32  None  Washington  Washington DC     USA      USD           0        None
# 33  None  Washington  Washington DC     USA      USD           0        None
# 34  None  Washington  Washington DC     USA      USD           0        None
# 35  None  Washington  Washington DC     USA      USD           0        None
# 36  None  Washington  Washington DC     USA      USD           0        None
# 37  None  Washington  Washington DC     USA      USD           0        None
# 38  None  Washington  Washington DC     USA      USD           0        None
# 39  None  Washington  Washington DC     USA      USD           0        None
# 40  None  Washington  Washington DC     USA      USD           0        None
# 41  None  Washington  Washington DC     USA      USD           0        None
# 42  None  Washington  Washington DC     USA      USD           0        None
# 43  None  Washington  Washington DC     USA      USD           0        None
# 44  None  Washington  Washington DC     USA      USD           0        None
# 45  None  Washington  Washington DC     USA      USD           0        None
# 46  None  Washington  Washington DC     USA      USD           0        None
# 47  None  Washington  Washington DC     USA      USD           0        None

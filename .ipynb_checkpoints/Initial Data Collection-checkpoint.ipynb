# %% [markdown]
# I just feel like a Jupyter Notebook should exist

# %%
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime

# %%
url1 = 'https://guide.michelin.com/us/en/public-rest/references.json'

# %%
reference = requests.get(url1)
reference
# Out:
# <Response [200]>

# %%
referenceData = r.json()
data
# Out:
# {'distinctionSlugOrder': ['3-stelle-michelin',
#   '3-stars-michelin',
#   '3-etoiles-michelin',
#   '3-estrellas-michelin',
#   '2-stelle-michelin',
#   '2-stars-michelin',
#   '2-etoiles-michelin',
#   '2-estrellas-michelin',
#   '1-stella-michelin',
#   '1-star-michelin',
#   '1-etoile-michelin',
#   '1-estrella-michelin',
#   'bib-gourmand',
#   'the-plate-michelin',
#   'assiette-michelin',
#   'el-plato-michelin',
#   'il-piatto-michelin',
#   'sustainable_gastronomy'],
#  'popularCountries': ['fr',
#   'gb',
#   'it',
#   'es',
#   'de',
#   'france',
#   'united-kingdom',
#   'italy',
#   'spain',
#   'germany'],
#  'regionMap': {'berkshire': {'country': 'gb', 'label': 'Berkshire'},
#   'cheshire-east': {'country': 'gb', 'label': 'Cheshire East'},
#   'jarva': {'country': 'ee', 'label': 'Järva'},
#   'southern-denmark': {'country': 'dk', 'label': 'Southern Denmark'},
#   'cheshire-west-and-chester': {'country': 'gb',
#    'label': 'Cheshire West and Chester'},
# ...

# %%
url2 = 'https://api.sail-personalize.com/v1/personalize/simple?pageviews=7&isMobile=0&visitorId=f1194c29-9f58-4a03-b704-09e60a171c34'

# %%
element = requests.get(url2)
element
# Out:
# <Response [401]>

# %%
elementData = element.json()
elementData
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~/anaconda3/lib/python3.11/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...
